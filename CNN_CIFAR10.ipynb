# %% [markdown]
# # Convolutional Neural Networks usando Keras e CIFAR-10
#
# ### 1. Carregando a base CIFAR-10 (imagens rotuladas em macro categorias)
#
# *** Mais informações em https://www.cs.toronto.edu/~kriz/cifar.html ***

# %%
import keras
from keras.datasets import cifar10

#carregando o dataset pré-embaralhado de treinamento bem como os dados de teste
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# %% [markdown]
# ### 2. Visualizando as primeiras 24 imagens do dataset de treinamento

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Redimensionando as imagens e dividindo cada pixel em cada imagem por 255

# %%
# redimensionamento [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Dividindo o dataset em treinamento, teste e validação

# %%
from keras.utils import np_utils

# "one-hot encode" aplicado aos rótulos
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# divindo dataset de treinamento em treinamento, teste e validação
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# impressão da forma do conjunto de treino
print('x_train shape:', x_train.shape)

# impressão do número de imagens nos datasets de treinamento, teste e validação
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# ('x_train shape:', (45000, 32, 32, 3))
# (45000, 'train samples')
# (10000, 'test samples')
# (5000, 'validation samples')

# %% [markdown]
# ### 5. Definindo a arquitetura do modelo (IMPORTANTE!)
#
# * 3 camadas convolucionais de tamanho progressivamente crescente
# * Máximo de camadas de "pooling" (2x2) seguidas por tais 3 camadas convolucionais
# * Uma camada do tipo totalmente conectada de 100 neurônios
# * Últimas camadas do tipo totalmente conectadas de 10 saídas (10 classes de categoria de imagem)
# * "Dropout" de 0,2-0,3

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# tentem com outras funções de ativação
# mais informações em https://keras.io/activations/

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_7 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 100)               204900
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 247,478
# Trainable params: 247,478
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compilando o modelo

# %%
# compilando o modelo escolhendo como se dará nossa perda, otimização e métricas (parâmetros do Keras)
# mais informações em https://keras.io/losses/
# mais informações em https://keras.io/optimizers/
# mais informações em https://keras.io/metrics/
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Treinando o modelo

# %%
from keras.callbacks import ModelCheckpoint   

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=64, epochs=15,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)

# tentem mudar o número de épocas de treinamento e verificar o comportamento de nosso algoritmo
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 542s - loss: 1.7638 - acc: 0.3541 - val_loss: 1.6722 - val_acc: 0.4086
#
# Epoch 00001: val_loss improved from inf to 1.67223, saving model to model.weights.best.hdf5
# Epoch 2/15
#  - 1259s - loss: 1.4089 - acc: 0.4914 - val_loss: 1.2800 - val_acc: 0.5426
#
# Epoch 00002: val_loss improved from 1.67223 to 1.28003, saving model to model.weights.best.hdf5
# Epoch 3/15
#  - 940s - loss: 1.2602 - acc: 0.5491 - val_loss: 1.5304 - val_acc: 0.4652
#
# Epoch 00003: val_loss did not improve from 1.28003
# Epoch 4/15
#  - 13358s - loss: 1.1533 - acc: 0.5948 - val_loss: 1.0274 - val_acc: 0.6328
#
# Epoch 00004: val_loss improved from 1.28003 to 1.02743, saving model to model.weights.best.hdf5
# Epoch 5/15
#  - 802s - loss: 1.0730 - acc: 0.6224 - val_loss: 1.2088 - val_acc: 0.5644
#
# Epoch 00005: val_loss did not improve from 1.02743
# Epoch 6/15
#  - 4918s - loss: 1.0134 - acc: 0.6456 - val_loss: 1.1235 - val_acc: 0.6274
#
# Epoch 00006: val_loss did not improve from 1.02743
# Epoch 7/15
#  - 537s - loss: 0.9705 - acc: 0.6628 - val_loss: 0.9308 - val_acc: 0.6684
#
# Epoch 00007: val_loss improved from 1.02743 to 0.93080, saving model to model.weights.best.hdf5
# Epoch 8/15
#  - 581s - loss: 0.9327 - acc: 0.6749 - val_loss: 0.9809 - val_acc: 0.6710
#
# Epoch 00008: val_loss did not improve from 0.93080
# Epoch 9/15
#  - 497s - loss: 0.9038 - acc: 0.6874 - val_loss: 0.9536 - val_acc: 0.6706
#
# Epoch 00009: val_loss did not improve from 0.93080
# Epoch 10/15
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-f14ec1a2020a> in <module>()
#       5 hist = model.fit(x_train, y_train, batch_size=64, epochs=15,
#       6           validation_data=(x_valid, y_valid), callbacks=[checkpointer],
# ----> 7           verbose=2, shuffle=True)
#       8
#       9 # tentem mudar o número de épocas de treinamento e verificar o comportamento de nosso algoritmo
#
# /Users/ahirtonlopes/anaconda2/lib/python2.7/site-packages/keras/engine/training.pyc in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1035                                         initial_epoch=initial_epoch,
#    1036                                         steps_per_epoch=steps_per_epoch,
# -> 1037                                         validation_steps=validation_steps)
#    1038
#    1039     def evaluate(self, x=None, y=None,
#
# /Users/ahirtonlopes/anaconda2/lib/python2.7/site-packages/keras/engine/training_arrays.pyc in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# /Users/ahirtonlopes/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# /Users/ahirtonlopes/anaconda2/lib/python2.7/site-packages/keras/backend/tensorflow_backend.pyc in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# /Users/ahirtonlopes/anaconda2/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %% [markdown]
# ### 8. Carregando o modelo com a melhor precisão de validação

# %%
# carregando os pesos que geraram a melhor precisão de validação
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Cálculo da precisão de classificação no dataset de testes

# %%
# avaliar e imprimir a precisão do teste
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# ('\n', 'Test accuracy:', 0.6712)

# %% [markdown]
# ### 10. Visualizar algumas predições
#
# As visualizações podem nos dar algumas dicas sobre por que a rede classifica erroneamente alguns objetos.

# %%
# obtendo previsões no conjunto de testes
y_hat = model.predict(x_test)

# definindo rótulos de texto (rótulos disponíveis na fonte original: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot de amostra aleatória de imagens de teste, rótulos preditos e a "ground truth" advinda do dataset CIFAR-10
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
    # amostras corretamente classificadas em verde, incorretamente classificadas em vermelho
