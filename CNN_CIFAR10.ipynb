# %% [markdown]
# # Convolutional Neural Networks usando Keras e CIFAR-10
#
# ### 1. Carregando a base CIFAR-10 (imagens rotuladas em macro categorias)
#
# *** Mais informações em https://www.cs.toronto.edu/~kriz/cifar.html ***

# %%
import keras
from keras.datasets import cifar10

#carregando o dataset pré-embaralhado de treinamento bem como os dados de teste
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# /Users/ahirtonlopes/anaconda2/lib/python2.7/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### 2. Visualizando as primeiras 24 imagens do dataset de treinamento

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))

# %% [markdown]
# ### 3. Redimensionando as imagens e dividindo cada pixel em cada imagem por 255

# %%
# redimensionamento [0,255] --> [0,1]
x_train = x_train.astype('float32')/255
x_test = x_test.astype('float32')/255

# %% [markdown]
# ### 4.  Dividindo o dataset em treinamento, teste e validação

# %%
from keras.utils import np_utils

# "one-hot encode" aplicado aos rótulos
num_classes = len(np.unique(y_train))
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# divindo dataset de treinamento em treinamento, teste e validação
(x_train, x_valid) = x_train[5000:], x_train[:5000]
(y_train, y_valid) = y_train[5000:], y_train[:5000]

# impressão da forma do conjunto de treino
print('x_train shape:', x_train.shape)

# impressão do número de imagens nos datasets de treinamento, teste e validação
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print(x_valid.shape[0], 'validation samples')
# Out:
# ('x_train shape:', (45000, 32, 32, 3))
# (45000, 'train samples')
# (10000, 'test samples')
# (5000, 'validation samples')

# %% [markdown]
# ### 5. Definindo a arquitetura do modelo (IMPORTANTE!)
#
# * 3 camadas convolucionais de tamanho progressivamente crescente
# * Máximo de camadas de "pooling" (2x2) seguidas por tais 3 camadas convolucionais
# * Uma camada do tipo totalmente conectada de 100 neurônios
# * Últimas camadas do tipo totalmente conectadas de 10 saídas (10 classes de categoria de imagem)
# * "Dropout" de 0,2-0,3

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout

model = Sequential()
model.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(32, 32, 3)))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=2))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(10, activation='softmax'))

# tentem com outras funções de ativação
# mais informações em https://keras.io/activations/

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        416
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 64)        8256
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 128)         32896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 4, 4, 128)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 4, 4, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               204900
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 247,478
# Trainable params: 247,478
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### 6. Compilando o modelo

# %%
# compilando o modelo escolhendo como se dará nossa perda, otimização e métricas (parâmetros do Keras)
# mais informações em https://keras.io/losses/
# mais informações em https://keras.io/optimizers/
# mais informações em https://keras.io/metrics/
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', 
                  metrics=['accuracy'])

# %% [markdown]
# ### 7. Treinando o modelo

# %%
from keras.callbacks import ModelCheckpoint   

checkpointer = ModelCheckpoint(filepath='model.weights.best.hdf5', verbose=1, 
                               save_best_only=True)
hist = model.fit(x_train, y_train, batch_size=64, epochs=15,
          validation_data=(x_valid, y_valid), callbacks=[checkpointer], 
          verbose=2, shuffle=True)

# tentem mudar o número de épocas de treinamento e verificar o comportamento de nosso algoritmo
# Out:
# Train on 45000 samples, validate on 5000 samples
# Epoch 1/15
#  - 785s - loss: 1.7389 - acc: 0.3673 - val_loss: 1.7346 - val_acc: 0.3864
#
# Epoch 00001: val_loss improved from inf to 1.73459, saving model to model.weights.best.hdf5
# Epoch 2/15
#  - 1137s - loss: 1.3882 - acc: 0.5041 - val_loss: 1.3211 - val_acc: 0.5274
#
# Epoch 00002: val_loss improved from 1.73459 to 1.32108, saving model to model.weights.best.hdf5
# Epoch 3/15
#  - 1105s - loss: 1.2299 - acc: 0.5633 - val_loss: 1.1797 - val_acc: 0.5840
#
# Epoch 00003: val_loss improved from 1.32108 to 1.17972, saving model to model.weights.best.hdf5
# Epoch 4/15
#  - 11360s - loss: 1.1314 - acc: 0.6028 - val_loss: 1.0071 - val_acc: 0.6422
#
# Epoch 00004: val_loss improved from 1.17972 to 1.00706, saving model to model.weights.best.hdf5
# Epoch 5/15
#  - 1072s - loss: 1.0540 - acc: 0.6330 - val_loss: 1.0347 - val_acc: 0.6408
#
# Epoch 00005: val_loss did not improve from 1.00706
# Epoch 6/15
#  - 727s - loss: 1.0009 - acc: 0.6536 - val_loss: 1.2210 - val_acc: 0.6046
#
# Epoch 00006: val_loss did not improve from 1.00706
# Epoch 7/15
#  - 595s - loss: 0.9615 - acc: 0.6676 - val_loss: 0.9926 - val_acc: 0.6584
#
# Epoch 00007: val_loss improved from 1.00706 to 0.99261, saving model to model.weights.best.hdf5
# Epoch 8/15
#  - 581s - loss: 0.9247 - acc: 0.6810 - val_loss: 0.9795 - val_acc: 0.6664
#
# Epoch 00008: val_loss improved from 0.99261 to 0.97954, saving model to model.weights.best.hdf5
# Epoch 9/15
#  - 583s - loss: 0.9003 - acc: 0.6904 - val_loss: 0.9130 - val_acc: 0.6868
#
# Epoch 00009: val_loss improved from 0.97954 to 0.91296, saving model to model.weights.best.hdf5
# Epoch 10/15
#  - 604s - loss: 0.8784 - acc: 0.6966 - val_loss: 0.9157 - val_acc: 0.6894
#
# Epoch 00010: val_loss did not improve from 0.91296
# Epoch 11/15
#  - 604s - loss: 0.8687 - acc: 0.7032 - val_loss: 0.8415 - val_acc: 0.7242
#
# Epoch 00011: val_loss improved from 0.91296 to 0.84150, saving model to model.weights.best.hdf5
# Epoch 12/15
#  - 618s - loss: 0.8550 - acc: 0.7085 - val_loss: 0.8594 - val_acc: 0.7140
#
# Epoch 00012: val_loss did not improve from 0.84150
# Epoch 13/15
#  - 617s - loss: 0.8443 - acc: 0.7136 - val_loss: 0.9687 - val_acc: 0.6812
#
# Epoch 00013: val_loss did not improve from 0.84150
# Epoch 14/15
#  - 569s - loss: 0.8375 - acc: 0.7160 - val_loss: 1.0033 - val_acc: 0.6816
#
# Epoch 00014: val_loss did not improve from 0.84150
# Epoch 15/15
#  - 529s - loss: 0.8365 - acc: 0.7202 - val_loss: 1.1980 - val_acc: 0.6148
#
# Epoch 00015: val_loss did not improve from 0.84150

# %% [markdown]
# ### 8. Carregando o modelo com a melhor precisão de validação

# %%
# carregando os pesos que geraram a melhor precisão de validação
model.load_weights('model.weights.best.hdf5')

# %% [markdown]
# ### 9. Cálculo da precisão de classificação no dataset de testes

# %%
# avaliar e imprimir a precisão do teste
score = model.evaluate(x_test, y_test, verbose=0)
print('\n', 'Test accuracy:', score[1])
# Out:
# ('\n', 'Test accuracy:', 0.7141)

# %% [markdown]
# ### 10. Visualizar algumas predições
#
# As visualizações podem nos dar algumas dicas sobre por que a rede classifica erroneamente alguns objetos.

# %%
# obtendo previsões no conjunto de testes
y_hat = model.predict(x_test)

# definindo rótulos de texto (rótulos disponíveis na fonte original: https://www.cs.toronto.edu/~kriz/cifar.html)
cifar10_labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
# plot de amostra aleatória de imagens de teste, rótulos preditos e a "ground truth" advinda do dataset CIFAR-10
fig = plt.figure(figsize=(20, 8))
for i, idx in enumerate(np.random.choice(x_test.shape[0], size=32, replace=False)):
    ax = fig.add_subplot(4, 8, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    pred_idx = np.argmax(y_hat[idx])
    true_idx = np.argmax(y_test[idx])
    ax.set_title("{} ({})".format(cifar10_labels[pred_idx], cifar10_labels[true_idx]),
                 color=("green" if pred_idx == true_idx else "red"))
    # amostras corretamente classificadas em verde, incorretamente classificadas em vermelho
